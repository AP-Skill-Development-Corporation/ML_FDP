# %%
Ridge
- add penalty term
- complex
- model performance will be low
Lasso
- removes the unwanted features
- loss of information
ElasticNet
- combination of lasso and ridge
- costfunction+(lambda(slope)^2)+lambda(|slope|)
- works well with the large data set

# %%
import pandas as pd
from sklearn.datasets import load_boston
boston=load_boston()

# %%
boston_df=pd.DataFrame(boston.data,columns=boston.feature_names)
boston_df["Target"]=boston.target
boston_df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  Target
# 0       15.3  396.90   4.98    24.0
# ...

# %%
boston_df.isna().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# Target     0
# dtype: int64

# %%
x=boston_df.iloc[:,0:13:1]
y=boston_df["Target"]

# %%
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
x_scale=scale.fit_transform(x)
x_scale
# Out:
# array([[-0.41978194,  0.28482986, -1.2879095 , ..., -1.45900038,
#          0.44105193, -1.0755623 ],
#        [-0.41733926, -0.48772236, -0.59338101, ..., -0.30309415,
#          0.44105193, -0.49243937],
#        [-0.41734159, -0.48772236, -0.59338101, ..., -0.30309415,
#          0.39642699, -1.2087274 ],
#        ...,
#        [-0.41344658, -0.48772236,  0.11573841, ...,  1.17646583,
#          0.44105193, -0.98304761],
#        [-0.40776407, -0.48772236,  0.11573841, ...,  1.17646583,
#          0.4032249 , -0.86530163],
#        [-0.41500016, -0.48772236,  0.11573841, ...,  1.17646583,
#          0.44105193, -0.66905833]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_scale,y,test_size=0.2,random_state=100)
from sklearn.linear_model import ElasticNet
model=ElasticNet()
model.fit(x_train,y_train)
# Out:
# ElasticNet()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.6305961799227735

# %%
model.coef_
# Out:
# array([-0.18734294,  0.14819469, -0.36969516,  0.48824412, -0.21171646,
#         2.2545172 , -0.        , -0.        , -0.        , -0.32120769,
#        -1.20339261,  0.41621862, -2.29708178])

# %% [markdown]
# ### Classification
# - 2 types
#     - binomial
#     - multinomial(more than two class labels)
#
# #### KNN(K Nearest Neighbors)
#
# - choose the value of k
# - find out the distances
# - compare the k nearest neighbors
# - predict the ouput which got majority vote

# %%
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Datasets/master/Classification/shirt.csv")

# %%
df
# Out:
#     Height  Weight Size
# 0      158      58    M
# 1      158      59    M
# 2      158      63    M
# 3      160      59    M
# 4      160      60    M
# 5      163      60    M
# 6      163      61    M
# 7      160      64    L
# 8      163      64    L
# 9      165      61    L
# 10     165      61    L
# 11     165      62    L
# 12     168      62    L
# 13     168      63    L
# 14     168      66    L
# 15     170      63    L
# 16     170      64    L
# 17     170      68    L

# %%
x=df[["Height","Weight"]]
y=df["Size"]

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=4)  # by calculating the sqrt(n),n=4
knn.fit(x,y)
# Out:
# KNeighborsClassifier(n_neighbors=4)

# %%
y_pred=knn.predict(x)

# %%
knn.predict([[161,61]])
# Out:
# array(['M'], dtype=object)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y,y_pred)
# Out:
# 0.8888888888888888

# %%
## Apply fruits dataset to knn

# %%
fruits_df=pd.read_csv("https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Datasets/master/Classification/fruit_data_with_colours.csv")

# %%
fruits_df
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin          mandarin    86    6.2     4.7         0.80
# 4             2   mandarin          mandarin    84    6.0     4.6         0.79
# 5             2   mandarin          mandarin    80    5.8     4.3         0.77
# 6             2   mandarin          mandarin    80    5.9     4.3         0.81
# 7             2   mandarin          mandarin    76    5.8     4.0         0.81
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# ...

# %%
fruits_df.isnull().sum()
# Out:
# fruit_label      0
# fruit_name       0
# fruit_subtype    0
# mass             0
# width            0
# height           0
# color_score      0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
fruits_df["fruit_subtype"]=lb.fit_transform(fruits_df["fruit_subtype"])

# %%
fruits_df
# Out:
#     fruit_label fruit_name  fruit_subtype  mass  width  height  color_score
# 0             1      apple              3   192    8.4     7.3         0.55
# 1             1      apple              3   180    8.0     6.8         0.59
# 2             1      apple              3   176    7.4     7.2         0.60
# 3             2   mandarin              4    86    6.2     4.7         0.80
# 4             2   mandarin              4    84    6.0     4.6         0.79
# 5             2   mandarin              4    80    5.8     4.3         0.77
# 6             2   mandarin              4    80    5.9     4.3         0.81
# 7             2   mandarin              4    76    5.8     4.0         0.81
# 8             1      apple              0   178    7.1     7.8         0.92
# 9             1      apple              0   172    7.4     7.0         0.89
# 10            1      apple              0   166    6.9     7.3         0.93
# ...

# %%
fruits_df.shape
# Out:
# (59, 7)

# %%
x=fruits_df.iloc[:,2:]
y=fruits_df["fruit_label"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=7)  # by calculating the sqrt(n),k=7
knn.fit(x,y)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred=knn.predict(x_test)

# %%
knn.predict([[3,192,8.4,7.3,0.55]])
# Out:
# array([4], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8333333333333334

# %%
correct=[0,1,1,0,1]
predicted=[0,0,1,1,1]
        actual
        1          0
pred
1       TP(2)    FP(1)

0       FN(1)     TN(1)
